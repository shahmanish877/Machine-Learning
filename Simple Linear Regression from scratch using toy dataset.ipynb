# %%
import numpy as np
np.random.seed(11)

# %%
# Prepare toy dataset

# Use equation y = 2x1 + 5

x1 = np.random.randn(100)
y = 2 * x1 + 5 + np.random.randn(100) * 0.9

# Plot the graph
import matplotlib.pyplot as plt
plt.scatter(x1, y)
plt.show()

# %%
x1 = (x1 - np.mean(x1))/np.std(x1)

plt.scatter(x1, y)
plt.show()

# %%
# Initialize w & b
w = -1
b = -1

epochs = 100
alpha = 0.1

# %%
def simple_linear_regression(w, b):
  y_hat = w * x1 + b
  return y_hat

# Compute RMSE
def RMSE(y_hat, y):
  return np.sqrt(np.sum(np.square(y_hat - y))/len(y))

# %%
# Next tune the W & b based on loss
y_hat = simple_linear_regression(w,  b)
plt.scatter(x1, y)
plt.plot(x1, y_hat)

# %%
for epoch in range(epochs):
  loss = RMSE(y_hat,  y)
  dw = np.sum(np.dot((y_hat - y), x1))/2
  db = np.sum(y_hat - y)/2

  # Update W & b
  w -= alpha * dw/len(x1)
  b -= alpha * db/len(x1)

  y_hat = simple_linear_regression(w, b)

  print("Loss in epoch {}: {}".format(epoch, RMSE(y_hat, y)))
# Out:
# Loss in epoch 0: 6.388966224154011
# Loss in epoch 1: 6.075407210719877
# Loss in epoch 2: 5.777829783828135
# Loss in epoch 3: 5.495449816240751
# Loss in epoch 4: 5.227523009680249
# Loss in epoch 5: 4.973342910718664
# Loss in epoch 6: 4.732239022555387
# Loss in epoch 7: 4.50357500724078
# Loss in epoch 8: 4.286746973098012
# Loss in epoch 9: 4.081181842279
# Loss in epoch 10: 3.886335793564209
# Loss in epoch 11: 3.70169277568335
# Loss in epoch 12: 3.5267630865988826
# Loss in epoch 13: 3.3610820143608913
# Loss in epoch 14: 3.204208535316223
# Loss in epoch 15: 3.055724065642941
# Loss in epoch 16: 2.915231262390481
# Loss in epoch 17: 2.7823528704445284
# Loss in epoch 18: 2.6567306121121756
# Loss in epoch 19: 2.5380241163461825
# Loss in epoch 20: 2.4259098850056584
# Loss in epoch 21: 2.3200802939915057
# Loss in epoch 22: 2.2202426276036373
# Loss in epoch 23: 2.1261181450450928
# Loss in epoch 24: 2.037441178642626
# Loss in epoch 25: 1.9539582640547373
# Loss in epoch 26: 1.8754273034794322
# Loss in epoch 27: 1.8016167636292832
# Loss in epoch 28: 1.7323049109753934
# Loss in epoch 29: 1.667279087430456
# Loss in epoch 30: 1.6063350301926556
# Loss in epoch 31: 1.549276239850608
# Loss in epoch 32: 1.4959134009990118
# Loss in epoch 33: 1.4460638594850332
# Loss in epoch 34: 1.399551159959181
# Loss in epoch 35: 1.3562046466234663
# Loss in epoch 36: 1.315859128961198
# Loss in epoch 37: 1.2783546128334615
# Loss in epoch 38: 1.243536095703962
# Loss in epoch 39: 1.211253423000747
# Loss in epoch 40: 1.1813612008550536
# Loss in epoch 41: 1.1537187587992495
# Loss in epoch 42: 1.1281901545802058
# Loss in epoch 43: 1.104644212158697
# Loss in epoch 44: 1.08295458329965
# Loss in epoch 45: 1.0629998229564357
# Loss in epoch 46: 1.0446634689194545
# Loss in epoch 47: 1.0278341169004486
# Loss in epoch 48: 1.0124054832914902
# Loss in epoch 49: 0.9982764491794078
# Loss in epoch 50: 0.9853510807072928
# Loss in epoch 51: 0.9735386224477673
# Loss in epoch 52: 0.9627534619891959
# Loss in epoch 53: 0.9529150653533275
# Loss in epoch 54: 0.9439478840990048
# Loss in epoch 55: 0.9357812359820903
# Loss in epoch 56: 0.9283491618187276
# Loss in epoch 57: 0.921590261738451
# Loss in epoch 58: 0.9154475143312704
# Loss in epoch 59: 0.9098680823149321
# Loss in epoch 60: 0.9048031083074856
# Loss in epoch 61: 0.900207504120882
# Loss in epoch 62: 0.8960397367277436
# Loss in epoch 63: 0.8922616137271858
# Loss in epoch 64: 0.8888380707739779
# Loss in epoch 65: 0.8857369630610272
# Loss in epoch 66: 0.8829288625759086
# Loss in epoch 67: 0.8803868625010797
# Loss in epoch 68: 0.8780863898035027
# Loss in epoch 69: 0.8760050267682097
# Loss in epoch 70: 0.8741223419745684
# Loss in epoch 71: 0.872419730994195
# Loss in epoch 72: 0.8708802669045254
# Loss in epoch 73: 0.8694885605598724
# Loss in epoch 74: 0.8682306304394786
# Loss in epoch 75: 0.867093781796425
# Loss in epoch 76: 0.8660664947589422
# Loss in epoch 77: 0.8651383209833784
# Loss in epoch 78: 0.8642997884227279
# Loss in epoch 79: 0.8635423137533133
# Loss in epoch 80: 0.8628581219923884
# Loss in epoch 81: 0.8622401728387926
# Loss in epoch 82: 0.8616820932753847
# Loss in epoch 83: 0.8611781159841002
# Loss in epoch 84: 0.8607230231407191
# Loss in epoch 85: 0.8603120951755834
# Loss in epoch 86: 0.8599410641076326
# Loss in epoch 87: 0.8596060710813991
# Loss in epoch 88: 0.8593036277594444
# Loss in epoch 89: 0.8590305812455868
# Loss in epoch 90: 0.8587840822368261
# Loss in epoch 91: 0.8585615561237955
# Loss in epoch 92: 0.8583606767806984
# Loss in epoch 93: 0.8581793428058188
# Loss in epoch 94: 0.8580156559927989
# Loss in epoch 95: 0.8578679018308365
# Loss in epoch 96: 0.857734531848811
# Loss in epoch 97: 0.8576141476340429
# Loss in epoch 98: 0.8575054863709949
# Loss in epoch 99: 0.8574074077587353

# %%
print(w, b)
# Out:
# 1.8285553939120869 4.99088843764802

# %%
y_pred = simple_linear_regression(w, b)
plt.scatter(x1, y)
plt.plot(x1, y_pred, color="red")
